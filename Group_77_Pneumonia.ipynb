# %%
# SCROLL FURTHER DOWN UNTIL "START HERE" FOR RELEVANT CODE!
# (all "harmful" code has been commented out)

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/Group 77 - Pneumonia/chest_xray/train/"
# Out:
# BACTERIA  NORMAL  VIRUS

# %%
import os
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

TRAIN_DIR = "/content/drive/My Drive/Group 77 - Pneumonia/chest_xray/train/"
TEST_DIR = "/content/drive/My Drive/Group 77 - Pneumonia/chest_xray/test/"

DIRECTORIES = [TRAIN_DIR, TEST_DIR]
CATEGORIES = ["NORMAL","BACTERIA", "VIRUS"]

# %%
for category in CATEGORIES:
    path = os.path.join(TRAIN_DIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        print("original image size: " + str(img_array.shape))
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break

img50 = cv2.resize(img_array, (50, 50))
img100 = cv2.resize(img_array, (100, 100))
img150 = cv2.resize(img_array, (150, 150))
img200 = cv2.resize(img_array, (200, 200))
img250 = cv2.resize(img_array, (250, 250))
img500 = cv2.resize(img_array, (500, 500))

plt.figure(figsize=(9, 6))
plt.subplot(2, 3, 1)
plt.imshow(img50, cmap="gray")

plt.subplot(2, 3, 2)
plt.imshow(img100, cmap="gray")

plt.subplot(2, 3, 3)
plt.imshow(img150, cmap="gray")

plt.subplot(2, 3, 4)
plt.imshow(img200, cmap="gray")

plt.subplot(2, 3, 5)
plt.imshow(img250, cmap="gray")

plt.subplot(2, 3, 6)
plt.imshow(img500, cmap="gray")

plt.tight_layout()
plt.show()
# Out:
# original image size: (1013, 1472)

# %%
IMG_SIZE = 224

img224 = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(img224, cmap = "gray")
plt.show()

# %%
# DO NOT RUN THIS CODE - IT TAKES FOREVER IN COLAB! 
# --> SCROLL DOWN UNTIL "START HERE"

# (it is just the Code, I've run on my machine: for a general understanding of the code)
# Relevant data has been pickled and stored in Google Drive --> see below

# Code above does not need to be run for all following tasks, but it also doesn't 
# hurt, it's just for documentation purposes (e.g. overview of the different resolutions)

"""
training_data = []
test_data = []

def create_data():
    for directory in DIRECTORIES:
        for category in CATEGORIES:
            path = os.path.join(directory, category)
            #index: NORMAL --> 0, BACTERIA --> 1, VIRUS --> 2
            class_num = CATEGORIES.index(category)
            for img in os.listdir(path):
                try:
                    img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                    if directory == TRAIN_DIR:
                        training_data.append([new_array, class_num])
                    elif directory == TEST_DIR:
                        test_data.append([new_array, class_num])
                except Exception as e:
                    print("faulty image")
                
create_data()
"""

# %%
# checking if all data has been processed
"""
print(len(training_data))
print(len(test_data))
"""

# %%
# creating normalized unshuffled arrays
"""
X_train_unshuffled = []
y_train_unshuffled = []

X_test_unshuffled = []
y_test_unshuffled = []

for features, label in training_data:
    X_train_unshuffled.append(features)
    y_train_unshuffled.append(label)
    
X_train_unshuffled = np.array(X_train_unshuffled).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

for features, label in test_data:
    X_test_unshuffled.append(features)
    y_test_unshuffled.append(label)
    
X_test_unshuffled = np.array(X_test_unshuffled).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
"""

# %%
# save data set - unshuffled
"""
import pickle

pickle_out = open("X_train_unshuffled.pickle", "wb")
pickle.dump(X_train, pickle_out)
pickle_out.close()

pickle_out = open("y_train_unshuffled.pickle", "wb")
pickle.dump(y_train, pickle_out)
pickle_out.close()

pickle_out = open("X_test_unshuffled.pickle", "wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

pickle_out = open("y_test_unshuffled.pickle", "wb")
pickle.dump(y_test, pickle_out)
pickle_out.close()
"""

# %%
# load dataset
"""
import pickle

X_train = pickle.load(open("X_train_unshuffled.pickle", "rb"))
y_train = pickle.load(open("y_train_unshuffled.pickle", "rb"))

X_test = pickle.load(open("X_test_unshuffled.pickle", "rb"))
y_test = pickle.load(open("y_test_unshuffled.pickle", "rb"))
"""

# %%
# shuffle data to improve learning behavior
"""
import random

random.shuffle(training_data)
random.shuffle(test_data)
"""

# %%
# creating normalized SHUFFLED arrays
"""
X_train = []
y_train = []

X_test = []
y_test = []

for features, label in training_data:
    X_train.append(features)
    y_train.append(label)
    
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

for features, label in test_data:
    X_test.append(features)
    y_test.append(label)
    
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
"""

# %%
# save data set --> method baseline data
"""
import pickle

pickle_out = open("X_train.pickle", "wb")
pickle.dump(X_train, pickle_out)
pickle_out.close()

pickle_out = open("y_train.pickle", "wb")
pickle.dump(y_train, pickle_out)
pickle_out.close()

pickle_out = open("X_test.pickle", "wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

pickle_out = open("y_test.pickle", "wb")
pickle.dump(y_test, pickle_out)
pickle_out.close()
"""

# %%
# START HERE

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/Group 77 - Pneumonia/pickle/"
# Out:
# X_test.pickle		  X_train_unshuffled.pickle  y_train.pickle
# X_test_unshuffled.pickle  y_test.pickle		     y_train_unshuffled.pickle
# X_train.pickle		  y_test_unshuffled.pickle

# %%
#load dataset --> method baseline!
import pickle

X_train = pickle.load(open("/content/drive/My Drive/Group 77 - Pneumonia/pickle/X_train.pickle", "rb"))
y_train = pickle.load(open("/content/drive/My Drive/Group 77 - Pneumonia/pickle/y_train.pickle", "rb"))

X_test = pickle.load(open("/content/drive/My Drive/Group 77 - Pneumonia/pickle/X_test.pickle", "rb"))
y_test = pickle.load(open("/content/drive/My Drive/Group 77 - Pneumonia/pickle/y_test.pickle", "rb"))

# %%
import numpy as np
X_train = np.asarray(X_train)
y_train = np.asarray(y_train)

X_test = np.asarray(X_test)
y_test = np.asarray(y_test)

X_train = X_train/255.0
X_test = X_test/255.0

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import time

NAME = "pneumonia-cnn-64x2-3ep-{}".format(time.strftime("%Y%m%d-%H%M%S"))

tensorboard = TensorBoard(log_dir = "logs/{}".format(NAME))

model = Sequential()

model.add(Conv2D(64, (3,3), input_shape = X_train.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(64))
model.add(Activation("relu"))

model.add(Dense(1))
model.add(Activation("sigmoid"))

model.compile(loss="binary_crossentropy", 
              optimizer="adam", 
              metrics=["accuracy"])

model.fit(X_train, y_train, batch_size=32, epochs=3, validation_split=0.4, callbacks = [tensorboard])
